# %%
with open("sample0303", "w") as f:
    r = 10
    c = 10
    x = 0
    y = 0
    f.write("{} {}\n".format(r, c))
    f.write("{} {}\n".format(y, x))
    for i in range(r):
        if i == 0:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(1))
                else:
                    f.write("{} ".format(1))
        else:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(1))
                elif j == 0:
                    f.write("{} ".format(1))
                else:
                    f.write("{} ".format(0))

# %%
with open("sample0304", "w") as f:
    r = 100
    c = 100
    x = 0
    y = 0
    f.write("{} {}\n".format(r, c))
    f.write("{} {}\n".format(y, x))
    for i in range(r):
        if i == 0:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(1))
                else:
                    f.write("{} ".format(1))
        else:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(1))
                elif j == 0:
                    f.write("{} ".format(1))
                else:
                    f.write("{} ".format(0))

# %%
with open("sample0305", "w") as f:
    r = 1000
    c = 1000
    x = 0
    y = 0
    f.write("{} {}\n".format(r, c))
    f.write("{} {}\n".format(y, x))
    for i in range(r):
        if i == 0:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(1))
                else:
                    f.write("{} ".format(1))
        else:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(1))
                elif j == 0:
                    f.write("{} ".format(1))
                else:
                    f.write("{} ".format(0))

# %%
with open("sample0306", "w") as f:
    r = 1000
    c = 1000
    x = 0
    y = 0
    f.write("{} {}\n".format(r, c))
    f.write("{} {}\n".format(y, x))
    for i in range(r):
        if i == 0:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(9))
                else:
                    f.write("{} ".format(9))
        else:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(9))
                elif j == 0:
                    f.write("{} ".format(9))
                else:
                    f.write("{} ".format(0))

# %%
with open("sample0307", "w") as f:
    r = 10
    c = 10
    x = 0
    y = 0
    f.write("{} {}\n".format(r, c))
    f.write("{} {}\n".format(y, x))
    for i in range(r):
        if i == 0:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(9))
                else:
                    f.write("{} ".format(9))
        elif i == r - 1:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(9))
                else:
                    f.write("{} ".format(9))
        else:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(9))
                else:
                    f.write("{} ".format(0))

# %%
with open("sample0308", "w") as f:
    r = 1000
    c = 1000
    x = 0
    y = 0
    f.write("{} {}\n".format(r, c))
    f.write("{} {}\n".format(y, x))
    for i in range(r):
        if i == 0:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(9))
                else:
                    f.write("{} ".format(9))
        elif i == r - 1:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(9))
                else:
                    f.write("{} ".format(9))
        else:
            for j in range(c):
                if j == c - 1:
                    f.write("{}\n".format(9))
                else:
                    f.write("{} ".format(0))
