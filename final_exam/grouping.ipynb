# %%
import pandas as pd

# %%
df = pd.read_csv('student_list.csv')
df
# Out:
#             學號 中文姓名                    英文姓名 NTHU OJ Account     科系班別碼  \
# 0    103060021  張仲霖                     NaN    DSC103060021  EECS106B
# 1    105000036  林曉彤         Lin  Hsiao-Tung    DSC105000036  UPMT106B
# 2    105041041  李昀庭                     NaN    DSC105041041  UPMT106B
# 3    105070032  潘美娟                     NaN    DSC105070032  UPMT106B
# 4    106020001  吳善棨            Wu  Shan-Chi    DSC106020001  SCI 106B
# ..         ...  ...                     ...             ...       ...
# 170  109065431  藍霓辰  Nichaporn Bunyakaranun    DSC109065431  ISA 109M
# 171  109065432  薩克凌         Sakkarin Krarat    DSC109065431  ISA 109M
# 172   1082117S  趙應方           JAW YING-FANG     DSC1082117S       NaN
# 173   1092085S  李雨橋                     NaN     DSC1092085S       NaN
# 174   1092127S  許方瑜                     NaN     DSC1092127S       NaN
#
#         科系班別中文   註記                      電子郵件
# 0    電資院學士班四年級  NaN    johnny840124@gmail.com
# ...

# %%
shuffle_df = df.sample(frac=1).reset_index(drop=True)
shuffle_df
# Out:
#             學號 中文姓名               英文姓名 NTHU OJ Account       科系班別碼     科系班別中文  \
# 0    108060025  莊心慈   Chuang  Hsin-Tzu      s108060025    EECS108B  電資院學士班二年級
# 1    109061589  謝昉澂  Hsieh  Fang-Cheng    DSC109061589    EE  109M     電機系碩士班
# 2    107021203  張浚哲                NaN    DSC107021203  MATH107B B     數學系三年級
# 3    107021172  廖國宇                NaN    DSC107021172  MATH107B A     數學系三年級
# 4    109062330  黃鈺臻                NaN      s109062330   CS  109BC   資工系一年級梅班
# ..         ...  ...                ...             ...         ...        ...
# 170  106081020  柯良諭                NaN    DSC106081020    LS  106B     生科系四年級
# 171  108060010  鄭德龢       Cheng  De-He    DSC108060010    EECS108B  電資院學士班二年級
# 172  108071003  李彥璋                NaN    DSC108071003   CS  108BB   資工系二年級華班
# 173  107011115  許晉綱                NaN    DSC107011115   ESS 108BA   工科系二年級清班
# 174  107000270  倫皓正      Lun-Hao-Zheng    DSC107000270   EE  107BA   電機系三年級清班
#
# ...

# %%
group_A = shuffle_df[::4]
group_A.to_csv("Group A.csv", index=False)
group_A
# Out:
#             學號  中文姓名                            英文姓名 NTHU OJ Account  \
# 0    108060025   莊心慈                Chuang  Hsin-Tzu      s108060025
# 4    109062330   黃鈺臻                             NaN      s109062330
# 8    107011217   謝侑呈                             NaN    DSC107011217
# 12   108020020   劉俊鍵                             NaN    DSC108020020
# 16   107012013   陳麒任                             NaN    DSC107012013
# 20   109065432   薩克凌                 Sakkarin Krarat    DSC109065431
# 24   107023012   許洸誠                             NaN    DSC107023012
# 28   105070032   潘美娟                             NaN    DSC105070032
# 32   107080004   邱沛昀                             NaN    DSC107080004
# 36   107061173   黃品崴                 Huang  Ping-Wei    DSC107061173
# 40   106061131   黃溢賢                             NaN    DSC106061131
# 44   108060061   劉兆洋                   LIU CHAO YANG      s108060032
# 48   108060003   呂玄祺                             NaN    DSC108032053
# ...

# %%
group_B = shuffle_df[1::4]
group_B.to_csv("Group B.csv", index=False)
group_B
# Out:
#             學號  中文姓名                        英文姓名 NTHU OJ Account       科系班別碼  \
# 1    109061589   謝昉澂           Hsieh  Fang-Cheng    DSC109061589    EE  109M
# 5    107021227   林祐丞                         NaN    DSC107021227  MATH107B B
# 9    106061152  陳  均                         NaN    DSC106061152   EE  106BA
# 13   109062327   許閎喆                         NaN    DSC109062327   CS  109BC
# 17   108006205   葛洋晴      Marcelo Andree Galindo   DSC_108006205   IBP 108BB
# 21   108020010   陳毅鴻                         NaN    DSC108020010    SCI 108B
# 25   108000203   王庭康                         NaN    DSC108000203   CS  108BC
# 29    1092127S   許方瑜                         NaN     DSC1092127S         NaN
# 33   109006268   蔡沃林                CHOY YUK LAM    DSC109006268   IBP 109BB
# 37   106080010   鄧翔宇                         NaN    DSC106080010    LSIP106B
# 41   108020007   黃瑜雰                         NaN    DSC108020007    SCI 108B
# ...

# %%
group_C = shuffle_df[2::4]
group_C.to_csv("Group C.csv", index=False)
group_C
# Out:
#             學號  中文姓名                               英文姓名 NTHU OJ Account  \
# 2    107021203   張浚哲                                NaN    DSC107021203
# 6    108006220   楊佳佳              Vicky Darika Djunawan    DSC108006220
# 10   107034039   葉映彤                                NaN    DSC107034039
# 14   109062226   孫柏翰                        Sun  Bo-Han    DSC109062226
# 18   107021115   錢珈鋒                                NaN    DSC107021115
# 22   109061225   許博翔                                NaN    DSC109061225
# 26   108011135   游珮綸                                NaN   DSC_108011135
# 30   106195003   許惟哲                                NaN    DSC106195003
# 34   107061222   馮渭中                                NaN    DSC107061173
# 38   108006204   梁美文                        Megan Leong    DSC108006204
# 42   108070002   簡紹翔                 Chien  Shao-Hsiang    DSC108070002
# 46   106060022   吳狄翰                         Wu  Ti-Han       106060022
# ...

# %%
group_D = shuffle_df[3::4]
group_D.to_csv("Group D.csv", index=False)
group_D
# Out:
#             學號  中文姓名                   英文姓名  NTHU OJ Account       科系班別碼  \
# 3    107021172   廖國宇                    NaN     DSC107021172  MATH107B A
# 7    108020022   周昱宏          Chou  Yu-Hong     DSC108020022   CS  108BC
# 11   105000036   林曉彤        Lin  Hsiao-Tung     DSC105000036    UPMT106B
# 15   108000115   李思澔           Lee  Szu-Hao     DSC108000115   CS  108BC
# 19   109062318   簡弘哲                    NaN       s109062318   CS  109BC
# 23   107021205   張意鴻                    NaN     DSC107021205  MATH107B B
# 27   109065429   林查克        Charkkri Limbud     DSC109065429    ISA 109M
# 31   107021131   黃詩晴                    NaN    DSC_107021131  MATH107B A
# 35   108010021   李泓錡                    NaN     DSC108010021    IPNS108B
# 39   108061242   張皓翔      Chang  Hao-Hsiang     DSC108061242   EE  108BB
# 43   108000201   邱奕傑                    NaN     DSC108000201   CS  108BC
# 47   107061108   陳柏臻                    NaN     DS2107061108   EE  107BA
# ...
