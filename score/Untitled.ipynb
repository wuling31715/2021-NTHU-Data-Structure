# %%
import pandas as pd

# %%
df = pd.read_csv('quiz1.csv', header=None)
df
# Out:
#            0                          1             2  \
# 0    2598233  April 14, 2021, 3:21 a.m.  DSC108070029
# 1    2598226  April 14, 2021, 3:13 a.m.  DSC108070029
# 2    2598222  April 14, 2021, 3:09 a.m.  DSC108070029
# 3    2597097  April 13, 2021, 5:48 p.m.  DSC107021104
# 4    2597072  April 13, 2021, 5:32 p.m.  DSC108060005
# ..       ...                        ...           ...
# 109  2586688  April 8, 2021, 12:31 a.m.  judgeDS_2018
# 110  2586526  April 7, 2021, 10:48 p.m.  judgeDS_2018
# 111  2586515  April 7, 2021, 10:45 p.m.  judgeDS_2018
# 112  2580456  April 2, 2021, 12:01 p.m.  judgeDS_2018
# 113  2580454  April 2, 2021, 11:58 a.m.  judgeDS_2018
#
#                                    3                   4      5
# 0    13162 - The Digit Board Problem  All Accepted (5/5)  C++11
# 1    13162 - The Digit Board Problem  All Accepted (5/5)  C++11
# 2    13162 - The Digit Board Problem  All Accepted (5/5)  C++11
# ...

# %%
id_list = df[2].tolist()
id_list
# Out:
# ['DSC108070029',
#  'DSC108070029',
#  'DSC108070029',
#  'DSC107021104',
#  'DSC108060005',
#  'TTzuyu',
#  's109062325',
#  'DSC108032053',
#  's109062102',
#  's109062102',
#  'DSC108000115',
#  's109062102',
#  's109062102',
#  's109062102',
#  'DSC108070022',
#  'DSC107011108',
#  's107062205',
#  's107062205',
#  'DSC108032053',
#  'DSC108032053',
#  's109062332',
#  'DSC108032053',
#  'DSC108032053',
#  'DSC108070029',
#  'DSC108032053',
#  'kev907',
#  'DSC108032053',
#  'DSC106034064',
#  'DSC109062161',
#  's107011115',
#  'DSC108070039',
#  'DSC108070039',
#  'MCYang',
#  's109062332',
#  'DSC108070039',
#  'DSC108070025',
#  'DSC107090002',
#  'DSC108020020',
#  'DSC108062373',
#  'DSC108062373',
#  'DSC107020008',
#  'DSC107011217',
#  'DSC107070024',
#  'DSC108020018',
#  'DSC107011217',
#  'DSC106034064',
#  'DSC107012013',
#  's109062318',
#  'DS2107061108',
#  'DSC107034039',
#  'DS2107061108',
#  'DSC108010021',
#  'DSC108010021',
#  'DSC107011115',
# ...

# %%
len(id_list)
# Out:
# 114

# %%
len(set(id_list))
# Out:
# 73
